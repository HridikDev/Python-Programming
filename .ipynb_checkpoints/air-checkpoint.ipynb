# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler

# 1. Load Titanic Dataset
air = pd.read_csv("C:/Users/hridi/Desktop/Entrance/Work/Python/AirQualityUCI.csv", sep=';',decimal=",")

# %%
air
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9466         NaN       NaN     NaN          NaN       NaN       NaN
# 9467         NaN       NaN     NaN          NaN       NaN       NaN
# 9468         NaN       NaN     NaN          NaN       NaN       NaN
# 9469         NaN       NaN     NaN          NaN       NaN       NaN
# 9470         NaN       NaN     NaN          NaN       NaN       NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
air["Datetime"] = pd.to_datetime(
air["Date"] + " " + air["Time"],
format="%d/%m/%Y %H.%M.%S", # Explicit format
errors="coerce"
)
# Drop old Date, Time columns
air = air.drop(columns=["Date", "Time"])
# Reorder columns (Datetime first)
air = air[["Datetime"] + [col for col in air.columns if col != "Datetime"]]
air.replace(-200, np.nan, inplace=True)
# Fill missing values (forward fill)
air.ffill(inplace=True)
print("Shape:", air.shape)
print("\nMissing values:\n", air.isna().sum())
print("\nData types:\n", air.dtypes)
# Out:
# Shape: (9471, 16)
#
# Missing values:
#  Datetime            0
# CO(GT)              0
# PT08.S1(CO)         0
# NMHC(GT)            0
# C6H6(GT)            0
# PT08.S2(NMHC)       0
# NOx(GT)             0
# PT08.S3(NOx)        0
# NO2(GT)             0
# PT08.S4(NO2)        0
# PT08.S5(O3)         0
# T                   0
# RH                  0
# AH                  0
# Unnamed: 15      9471
# Unnamed: 16      9471
# dtype: int64
#
# Data types:
#  Datetime         datetime64[ns]
# CO(GT)                  float64
# PT08.S1(CO)             float64
# NMHC(GT)                float64
# C6H6(GT)                float64
# PT08.S2(NMHC)           float64
# NOx(GT)                 float64
# PT08.S3(NOx)            float64
# NO2(GT)                 float64
# PT08.S4(NO2)            float64
# PT08.S5(O3)             float64
# T                       float64
# RH                      float64
# AH                      float64
# Unnamed: 15             float64
# ...

# %%
air.head(10)
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2,6       1360.0     150.0     11,9         1046.0
# 1  10/03/2004  19.00.00      2       1292.0     112.0      9,4          955.0
# 2  10/03/2004  20.00.00    2,2       1402.0      88.0      9,0          939.0
# 3  10/03/2004  21.00.00    2,2       1376.0      80.0      9,2          948.0
# 4  10/03/2004  22.00.00    1,6       1272.0      51.0      6,5          836.0
# 5  10/03/2004  23.00.00    1,2       1197.0      38.0      4,7          750.0
# 6  11/03/2004  00.00.00    1,2       1185.0      31.0      3,6          690.0
# 7  11/03/2004  01.00.00      1       1136.0      31.0      3,3          672.0
# 8  11/03/2004  02.00.00    0,9       1094.0      24.0      2,3          609.0
# 9  11/03/2004  03.00.00    0,6       1010.0      19.0      1,7          561.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# ...

# %%
air.tail(5)
# Out:
#      Date Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 9466  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9467  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9468  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9469  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9470  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
#
#       PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)    T   RH   AH  \
# 9466           NaN      NaN           NaN          NaN  NaN  NaN  NaN
# 9467           NaN      NaN           NaN          NaN  NaN  NaN  NaN
# 9468           NaN      NaN           NaN          NaN  NaN  NaN  NaN
# 9469           NaN      NaN           NaN          NaN  NaN  NaN  NaN
# 9470           NaN      NaN           NaN          NaN  NaN  NaN  NaN
#
#       Unnamed: 15  Unnamed: 16
# 9466          NaN          NaN
# ...

# %%
air.isnull().sum()
# Out:
# Date              114
# Time              114
# CO(GT)            114
# PT08.S1(CO)       114
# NMHC(GT)          114
# C6H6(GT)          114
# PT08.S2(NMHC)     114
# NOx(GT)           114
# PT08.S3(NOx)      114
# NO2(GT)           114
# PT08.S4(NO2)      114
# PT08.S5(O3)       114
# T                 114
# RH                114
# AH                114
# Unnamed: 15      9471
# Unnamed: 16      9471
# dtype: int64

# %%
air.describe()
# Out:
#        PT08.S1(CO)     NMHC(GT)  PT08.S2(NMHC)      NOx(GT)  PT08.S3(NOx)  \
# count  9357.000000  9357.000000    9357.000000  9357.000000   9357.000000
# mean   1048.990061  -159.090093     894.595276   168.616971    794.990168
# std     329.832710   139.789093     342.333252   257.433866    321.993552
# min    -200.000000  -200.000000    -200.000000  -200.000000   -200.000000
# 25%     921.000000  -200.000000     711.000000    50.000000    637.000000
# 50%    1053.000000  -200.000000     895.000000   141.000000    794.000000
# 75%    1221.000000  -200.000000    1105.000000   284.000000    960.000000
# max    2040.000000  1189.000000    2214.000000  1479.000000   2683.000000
#
#            NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  Unnamed: 15  Unnamed: 16
# count  9357.000000   9357.000000  9357.000000          0.0          0.0
# mean     58.148873   1391.479641   975.072032          NaN          NaN
# std     126.940455    467.210125   456.938184          NaN          NaN
# ...

# %%
plt.figure(figsize=(12,6))
plt.plot(air["Datetime"],air["CO(GT)"],color="blue")
plt.title("CO Concentration Over Time")
plt.xlabel("Datetime")
plt.ylabel("CO (mg/m^3)")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(air["C6H6(GT)"].dropna(), bins=50, kde=True, color="green")
plt.title("Distribution of Benzene (C6H6)")
plt.xlabel("C6H6 (μg/m^3)")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.heatmap(air.corr(numeric_only=True), cmap="coolwarm", annot=False)
plt.title("Correlation Heatmap of Pollutants")
plt.show()

# %%
daily_co = air.resample("D", on="Datetime")["CO(GT)"].mean()
plt.figure(figsize=(12,6))
plt.plot(daily_co.index, daily_co, color="red")
plt.title("Daily Average CO Concentration")
plt.xlabel("Date")
plt.ylabel("CO (mg/m^3)")
plt.show()
